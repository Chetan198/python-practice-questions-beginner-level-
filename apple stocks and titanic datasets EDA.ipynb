# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\hp\\Desktop\\tested.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.drop("Cabin",axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df['Ticket'].sort_values(ascending=True)
# Out:
# 335         110469
# 158         110489
# 236         110813
# 191         111163
# 266         112051
#           ...
# 222    W./C. 14266
# 244     W./C. 6607
# 33      W./C. 6607
# 167     W./C. 6608
# 14     W.E.P. 5734
# Name: Ticket, Length: 418, dtype: object

# %%
df.groupby('Sex')['Fare'].mean()
# Out:
# Sex
# female    49.747699
# male      27.527877
# Name: Fare, dtype: float64

# %%
df_new=df.groupby('Sex')['Fare'].mean()

# %%
df_new
# Out:
# Sex
# female    49.747699
# male      27.527877
# Name: Fare, dtype: float64

# %%
df_new=df_new.reset_index()

# %%
df_new
# Out:
#       Sex       Fare
# 0  female  49.747699
# 1    male  27.527877

# %% [markdown]
# # Write an efficient function that takes stock_prices and returns the best profit  made from one purchase and one sale of one share of Apple stock yesterday.

# %%
stock_prices=[1,44,89,78,9,45,36,7,26,478]
def get_max_profit(stock_prices):
    max_profit = 0

    # Go through every time
    for outer_time in range(len(stock_prices)):

        # For every time, go through every other time
        for inner_time in range(len(stock_prices)):
            # For each pair, find the earlier and later times
            earlier_time = min(outer_time, inner_time)
            later_time   = max(outer_time, inner_time)

            # And use those to find the earlier and later prices
            earlier_price = stock_prices[earlier_time]
            later_price   = stock_prices[later_time]
            #stock_price =  stock_prices[time at which it was selled or bought] 
            # See what our profit would be if we bought at the
            # earlier price and sold at the later price
            potential_profit = later_price - earlier_price

            # Update max_profit if we can do better
            max_profit = max(max_profit, potential_profit)

    return max_profit
get_max_profit(stock_prices)
# Out:
# 477

# %%
len(stock_prices)
# Out:
# 10
